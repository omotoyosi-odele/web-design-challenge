# %%
import pandas as pd
import pprint
import os


data_csv = pd.read_csv("city_data.csv")

# %%
city_data_html = data_csv.to_html(index=False)
city_data_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>City</th>\n      <th>Cloudiness</th>\n      <th>Country</th>\n      <th>Date</th>\n      <th>Humidity</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Max Temp</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>Alice Springs</td>\n      <td>0</td>\n      <td>AU</td>\n      <td>1587234135</td>\n      <td>55</td>\n      <td>-23.70</td>\n      <td>133.88</td>\n      <td>60.80</td>\n      <td>4.70</td>\n    </tr>\n    <tr>\n      <td>Rikitea</td>\n      <td>1</td>\n      <td>PF</td>\n      <td>1587234135</td>\n      <td>70</td>\n      <td>-23.12</td>\n      <td>-134.97</td>\n      <td>76.78</td>\n      <td>4.68</td>\n    </tr>\n    <tr>\n      <td>Haines Junction</td>\n      <td>1</td>\n      <td>CA</td>\n      <td>1587234136</td>\n      <td>50</td>\n      <td>60.75</td>\n      <td>-137.51</td>\n      <td>42.53</td>\n      <td>1.50</td>\n 
# ...
